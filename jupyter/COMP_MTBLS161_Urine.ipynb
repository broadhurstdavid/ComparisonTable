# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS161_Urine',
        'tables/PCR_MTBLS161_Urine',
        'tables/PCLR_MTBLS161_Urine',
        'tables/RF_MTBLS161_Urine',
        'tables/SVM_MTBLS161_Urine']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Urine   5.58e-06  0.93 (0.83, 0.99)   0.85 (0.68, 0.9)
# tables/PCR_MTBLS161_Urine   1.61e-05  0.85 (0.73, 0.96)  0.85 (0.39, 0.95)
# tables/PCLR_MTBLS161_Urine  1.61e-05  0.85 (0.73, 0.93)  0.85 (0.45, 0.92)
# tables/RF_MTBLS161_Urine    1.03e-07   0.99 (0.98, 1.0)  0.92 (0.86, 0.97)
# tables/SVM_MTBLS161_Urine   8.21e-06  0.92 (0.82, 0.98)  0.78 (0.61, 0.94)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Urine    0.84 (0.7, 0.89)  0.91 (0.65, 1.0)        0.76
# tables/PCR_MTBLS161_Urine   0.87 (0.71, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/PCLR_MTBLS161_Urine  0.87 (0.73, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/RF_MTBLS161_Urine     0.95 (0.86, 1.0)   0.91 (0.8, 1.0)        0.94
# tables/SVM_MTBLS161_Urine   0.85 (0.74, 0.93)  0.74 (0.51, 1.0)        0.82
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Urine   0.88 (0.67, 0.93)  0.54 (0.27, 0.77)
# tables/PCR_MTBLS161_Urine    0.87 (0.0, 0.95)     nan (nan, nan)
# tables/PCLR_MTBLS161_Urine   0.87 (0.0, 0.94)     nan (nan, nan)
# tables/RF_MTBLS161_Urine    0.93 (0.87, 0.98)     nan (nan, nan)
# tables/SVM_MTBLS161_Urine   0.79 (0.62, 0.95)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                            manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS161_Urine       0.05  0.79     0.72      0.75        0.82
# tables/PCR_MTBLS161_Urine       0.54  0.58     0.61      0.67        0.73
# tables/PCLR_MTBLS161_Urine      0.54  0.58     0.61      0.67        0.73
# tables/RF_MTBLS161_Urine        0.36  0.64     0.56      0.67        0.55
# tables/SVM_MTBLS161_Urine       0.02  0.83     0.78      0.82        0.82
#
#                            specificity F1score     R2
# method
# tables/PLS_MTBLS161_Urine         0.57    0.78  -0.13
# tables/PCR_MTBLS161_Urine         0.43     0.7    nan
# tables/PCLR_MTBLS161_Urine        0.43     0.7    nan
# tables/RF_MTBLS161_Urine          0.57     0.6    nan
# tables/SVM_MTBLS161_Urine         0.71    0.82    nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Urine   5.58e-06  0.93 (0.83, 0.99)   0.85 (0.68, 0.9)
# tables/PCR_MTBLS161_Urine   1.61e-05  0.85 (0.73, 0.96)  0.85 (0.39, 0.95)
# tables/PCLR_MTBLS161_Urine  1.61e-05  0.85 (0.73, 0.93)  0.85 (0.45, 0.92)
# tables/RF_MTBLS161_Urine    1.03e-07   0.99 (0.98, 1.0)  0.92 (0.86, 0.97)
# tables/SVM_MTBLS161_Urine   8.21e-06  0.92 (0.82, 0.98)  0.78 (0.61, 0.94)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Urine    0.84 (0.7, 0.89)  0.91 (0.65, 1.0)        0.76
# tables/PCR_MTBLS161_Urine   0.87 (0.71, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/PCLR_MTBLS161_Urine  0.87 (0.73, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/RF_MTBLS161_Urine     0.95 (0.86, 1.0)   0.91 (0.8, 1.0)        0.94
# tables/SVM_MTBLS161_Urine   0.85 (0.74, 0.93)  0.74 (0.51, 1.0)        0.82
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Urine   0.88 (0.67, 0.93)  0.54 (0.27, 0.77)
# tables/PCR_MTBLS161_Urine    0.87 (0.0, 0.95)     nan (nan, nan)
# tables/PCLR_MTBLS161_Urine   0.87 (0.0, 0.94)     nan (nan, nan)
# tables/RF_MTBLS161_Urine    0.93 (0.87, 0.98)     nan (nan, nan)
# tables/SVM_MTBLS161_Urine   0.79 (0.62, 0.95)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Urine   5.58e-06  0.93 (0.83, 0.99)   0.85 (0.68, 0.9)
# tables/PCR_MTBLS161_Urine   1.61e-05  0.85 (0.73, 0.96)  0.85 (0.39, 0.95)
# tables/PCLR_MTBLS161_Urine  1.61e-05  0.85 (0.73, 0.93)  0.85 (0.45, 0.92)
# tables/RF_MTBLS161_Urine    1.03e-07   0.99 (0.98, 1.0)  0.92 (0.86, 0.97)
# tables/SVM_MTBLS161_Urine   8.21e-06  0.92 (0.82, 0.98)  0.78 (0.61, 0.94)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Urine    0.84 (0.7, 0.89)  0.91 (0.65, 1.0)        0.76
# tables/PCR_MTBLS161_Urine   0.87 (0.71, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/PCLR_MTBLS161_Urine  0.87 (0.73, 0.96)   0.87 (0.0, 1.0)        0.82
# tables/RF_MTBLS161_Urine     0.95 (0.86, 1.0)   0.91 (0.8, 1.0)        0.94
# tables/SVM_MTBLS161_Urine   0.85 (0.74, 0.93)  0.74 (0.51, 1.0)        0.82
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Urine   0.88 (0.67, 0.93)  0.54 (0.27, 0.77)
# tables/PCR_MTBLS161_Urine    0.87 (0.0, 0.95)     nan (nan, nan)
# tables/PCLR_MTBLS161_Urine   0.87 (0.0, 0.94)     nan (nan, nan)
# tables/RF_MTBLS161_Urine    0.93 (0.87, 0.98)     nan (nan, nan)
# tables/SVM_MTBLS161_Urine   0.79 (0.62, 0.95)     nan (nan, nan)
