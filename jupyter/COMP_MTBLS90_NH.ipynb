# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS90_NH',
        'tables/PCR_MTBLS90_NH',
        'tables/PCLR_MTBLS90_NH',
        'tables/RF_MTBLS90_NH',
        'tables/SVM_MTBLS90_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS90_NH    5.17e-88  0.87 (0.84, 0.89)   0.82 (0.8, 0.84)
# tables/PCR_MTBLS90_NH    1.63e-77  0.85 (0.81, 0.87)  0.79 (0.76, 0.82)
# tables/PCLR_MTBLS90_NH   2.28e-72  0.79 (0.76, 0.82)  0.79 (0.76, 0.82)
# tables/RF_MTBLS90_NH    1.90e-102   0.9 (0.88, 0.91)  0.82 (0.79, 0.85)
# tables/SVM_MTBLS90_NH    7.60e-82  0.86 (0.83, 0.88)  0.81 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS90_NH    0.81 (0.8, 0.83)  0.83 (0.78, 0.87)        0.81
# tables/PCR_MTBLS90_NH   0.79 (0.77, 0.82)  0.78 (0.73, 0.84)        0.79
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)  0.78 (0.75, 0.82)         0.8
# tables/RF_MTBLS90_NH     0.82 (0.8, 0.84)  0.81 (0.75, 0.87)        0.82
# tables/SVM_MTBLS90_NH   0.81 (0.79, 0.83)  0.81 (0.74, 0.84)        0.81
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS90_NH   0.82 (0.79, 0.85)   0.4 (0.34, 0.44)
# tables/PCR_MTBLS90_NH   0.79 (0.76, 0.82)  0.33 (0.26, 0.38)
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)     nan (nan, nan)
# tables/RF_MTBLS90_NH    0.82 (0.78, 0.85)     nan (nan, nan)
# tables/SVM_MTBLS90_NH   0.81 (0.76, 0.84)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS90_NH    5.17e-88  0.87 (0.84, 0.89)   0.82 (0.8, 0.84)
# tables/PCR_MTBLS90_NH    1.63e-77  0.85 (0.81, 0.87)  0.79 (0.76, 0.82)
# tables/PCLR_MTBLS90_NH   2.28e-72  0.79 (0.76, 0.82)  0.79 (0.76, 0.82)
# tables/RF_MTBLS90_NH    1.90e-102   0.9 (0.88, 0.91)  0.82 (0.79, 0.85)
# tables/SVM_MTBLS90_NH    7.60e-82  0.86 (0.83, 0.88)  0.81 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS90_NH    0.81 (0.8, 0.83)  0.83 (0.78, 0.87)        0.81
# tables/PCR_MTBLS90_NH   0.79 (0.77, 0.82)  0.78 (0.73, 0.84)        0.79
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)  0.78 (0.75, 0.82)         0.8
# tables/RF_MTBLS90_NH     0.82 (0.8, 0.84)  0.81 (0.75, 0.87)        0.82
# tables/SVM_MTBLS90_NH   0.81 (0.79, 0.83)  0.81 (0.74, 0.84)        0.81
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS90_NH   0.82 (0.79, 0.85)   0.4 (0.34, 0.44)
# tables/PCR_MTBLS90_NH   0.79 (0.76, 0.82)  0.33 (0.26, 0.38)
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)     nan (nan, nan)
# tables/RF_MTBLS90_NH    0.82 (0.78, 0.85)     nan (nan, nan)
# tables/SVM_MTBLS90_NH   0.81 (0.76, 0.84)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS90_NH    5.17e-88  0.87 (0.84, 0.89)   0.82 (0.8, 0.84)
# tables/PCR_MTBLS90_NH    1.63e-77  0.85 (0.81, 0.87)  0.79 (0.76, 0.82)
# tables/PCLR_MTBLS90_NH   2.28e-72  0.79 (0.76, 0.82)  0.79 (0.76, 0.82)
# tables/RF_MTBLS90_NH    1.90e-102   0.9 (0.88, 0.91)  0.82 (0.79, 0.85)
# tables/SVM_MTBLS90_NH    7.60e-82  0.86 (0.83, 0.88)  0.81 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS90_NH    0.81 (0.8, 0.83)  0.83 (0.78, 0.87)        0.81
# tables/PCR_MTBLS90_NH   0.79 (0.77, 0.82)  0.78 (0.73, 0.84)        0.79
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)  0.78 (0.75, 0.82)         0.8
# tables/RF_MTBLS90_NH     0.82 (0.8, 0.84)  0.81 (0.75, 0.87)        0.82
# tables/SVM_MTBLS90_NH   0.81 (0.79, 0.83)  0.81 (0.74, 0.84)        0.81
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS90_NH   0.82 (0.79, 0.85)   0.4 (0.34, 0.44)
# tables/PCR_MTBLS90_NH   0.79 (0.76, 0.82)  0.33 (0.26, 0.38)
# tables/PCLR_MTBLS90_NH  0.79 (0.76, 0.82)     nan (nan, nan)
# tables/RF_MTBLS90_NH    0.82 (0.78, 0.85)     nan (nan, nan)
# tables/SVM_MTBLS90_NH   0.81 (0.76, 0.84)     nan (nan, nan)
