# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_ST000369',
        'tables/PCR_ST000369',
        'tables/PCLR_ST000369',
        'tables/RF_ST000369',
        'tables/SVM_ST000369']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000369   1.82e-16  0.96 (0.93, 0.98)  0.89 (0.79, 0.94)
# tables/PCR_ST000369   5.28e-11  0.87 (0.82, 0.92)  0.79 (0.67, 0.86)
# tables/PCLR_ST000369  4.38e-09  0.77 (0.71, 0.86)  0.79 (0.73, 0.86)
# tables/RF_ST000369    5.47e-07  0.78 (0.71, 0.87)   0.7 (0.62, 0.78)
# tables/SVM_ST000369   4.61e-17  0.97 (0.93, 0.99)   0.8 (0.55, 0.96)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_ST000369   0.88 (0.81, 0.92)  0.84 (0.61, 0.95)        0.93
# tables/PCR_ST000369   0.76 (0.57, 0.85)  0.66 (0.31, 0.86)        0.87
# tables/PCLR_ST000369  0.74 (0.62, 0.87)   0.7 (0.58, 0.84)        0.84
# tables/RF_ST000369    0.75 (0.58, 0.88)  0.34 (0.23, 0.51)        0.93
# tables/SVM_ST000369    0.96 (0.9, 0.98)    0.5 (0.0, 0.91)        0.99
#
#                                 F1score                 R2
# method
# tables/PLS_ST000369   0.86 (0.71, 0.92)  0.59 (0.49, 0.66)
# tables/PCR_ST000369   0.71 (0.41, 0.86)  0.37 (0.23, 0.49)
# tables/PCLR_ST000369  0.72 (0.61, 0.83)     nan (nan, nan)
# tables/RF_ST000369    0.47 (0.34, 0.62)     nan (nan, nan)
# tables/SVM_ST000369    0.66 (0.0, 0.94)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                      manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_ST000369   4.52e-06  0.89     0.78      0.65        0.89
# tables/PCR_ST000369   1.66e-04  0.82      0.8      0.71        0.79
# tables/PCLR_ST000369  2.77e-06  0.85     0.84      0.74        0.89
# tables/RF_ST000369        0.13  0.63     0.61       0.5        0.16
# tables/SVM_ST000369   6.65e-06  0.89     0.86      0.88        0.74
#
#                      specificity F1score    R2
# method
# tables/PLS_ST000369          0.7    0.76  0.31
# tables/PCR_ST000369          0.8    0.75  0.19
# tables/PCLR_ST000369         0.8    0.81   nan
# tables/RF_ST000369           0.9    0.24   nan
# tables/SVM_ST000369         0.93     0.8   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000369   1.82e-16  0.96 (0.93, 0.98)  0.89 (0.79, 0.94)
# tables/PCR_ST000369   5.28e-11  0.87 (0.82, 0.92)  0.79 (0.67, 0.86)
# tables/PCLR_ST000369  4.38e-09  0.77 (0.71, 0.86)  0.79 (0.73, 0.86)
# tables/RF_ST000369    5.47e-07  0.78 (0.71, 0.87)   0.7 (0.62, 0.78)
# tables/SVM_ST000369   4.61e-17  0.97 (0.93, 0.99)   0.8 (0.55, 0.96)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_ST000369   0.88 (0.81, 0.92)  0.84 (0.61, 0.95)        0.93
# tables/PCR_ST000369   0.76 (0.57, 0.85)  0.66 (0.31, 0.86)        0.87
# tables/PCLR_ST000369  0.74 (0.62, 0.87)   0.7 (0.58, 0.84)        0.84
# tables/RF_ST000369    0.75 (0.58, 0.88)  0.34 (0.23, 0.51)        0.93
# tables/SVM_ST000369    0.96 (0.9, 0.98)    0.5 (0.0, 0.91)        0.99
#
#                                 F1score                 R2
# method
# tables/PLS_ST000369   0.86 (0.71, 0.92)  0.59 (0.49, 0.66)
# tables/PCR_ST000369   0.71 (0.41, 0.86)  0.37 (0.23, 0.49)
# tables/PCLR_ST000369  0.72 (0.61, 0.83)     nan (nan, nan)
# tables/RF_ST000369    0.47 (0.34, 0.62)     nan (nan, nan)
# tables/SVM_ST000369    0.66 (0.0, 0.94)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000369   1.82e-16  0.96 (0.93, 0.98)  0.89 (0.79, 0.94)
# tables/PCR_ST000369   5.28e-11  0.87 (0.82, 0.92)  0.79 (0.67, 0.86)
# tables/PCLR_ST000369  4.38e-09  0.77 (0.71, 0.86)  0.79 (0.73, 0.86)
# tables/RF_ST000369    5.47e-07  0.78 (0.71, 0.87)   0.7 (0.62, 0.78)
# tables/SVM_ST000369   4.61e-17  0.97 (0.93, 0.99)   0.8 (0.55, 0.96)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_ST000369   0.88 (0.81, 0.92)  0.84 (0.61, 0.95)        0.93
# tables/PCR_ST000369   0.76 (0.57, 0.85)  0.66 (0.31, 0.86)        0.87
# tables/PCLR_ST000369  0.74 (0.62, 0.87)   0.7 (0.58, 0.84)        0.84
# tables/RF_ST000369    0.75 (0.58, 0.88)  0.34 (0.23, 0.51)        0.93
# tables/SVM_ST000369    0.96 (0.9, 0.98)    0.5 (0.0, 0.91)        0.99
#
#                                 F1score                 R2
# method
# tables/PLS_ST000369   0.86 (0.71, 0.92)  0.59 (0.49, 0.66)
# tables/PCR_ST000369   0.71 (0.41, 0.86)  0.37 (0.23, 0.49)
# tables/PCLR_ST000369  0.72 (0.61, 0.83)     nan (nan, nan)
# tables/RF_ST000369    0.47 (0.34, 0.62)     nan (nan, nan)
# tables/SVM_ST000369    0.66 (0.0, 0.94)     nan (nan, nan)
