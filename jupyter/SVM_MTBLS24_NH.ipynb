# %% [markdown]
# ## SVM

# %% [markdown]
# ----

# %% [markdown]
# ### 1. Import Modules

# %%
import numpy as np
import pandas as pd
import cimcb as cb
from sklearn.model_selection import train_test_split

print('All packages successfully loaded')
# Out:
# Using TensorFlow backend.
# All packages successfully loaded

# %% [markdown]
# ### 2. Load data and peak sheet

# %%
home = 'data/' 
file = 'MTBLS24.xlsx' 

DataTable,PeakTable = cb.utils.load_dataXL(home + file, DataSheet='Data', PeakSheet='Peak')
# Out:
# Loadings PeakFile: Peak
# Loadings DataFile: Data
# Data Table & Peak Table is suitable.
# TOTAL SAMPLES: 106 TOTAL PEAKS: 701
# Done!

# %% [markdown]
# ### 3. Extract X & Y

# %%
peaklist = PeakTable['Name']
DataTable2 = DataTable[(DataTable['Class']==0) | (DataTable['Class']==1)]
Y = DataTable2['Class'].values 

# Extract and scale the metabolite data from the DataTable
peaklist = PeakTable['Name']                           
XT = DataTable2[peaklist]                                    
#XTlog = np.log(XT)                                          
XTscale = cb.utils.scale(np.array(XT), method='auto')              
XTknn = cb.utils.knnimpute(XTscale, k=3)

# %% [markdown]
# ### 4. Hyperparameters optimisation

# %%
# param_dict
# C_range = [2**-5, 2**-3, 2**-1, 2**1, 2**3, 2**5, 2**7, 2**9, 2**11, 2**13, 2**15]
# gamma_range = [2**-15, 2**-13, 2**-11, 2**-9, 2**-7, 2**-5, 2**-3, 2**-1, 2**1, 2**3]
C_range = [2**-5, 2**-3, 2**-1, 2**1, 2**3, 2**5, 2**7, 2**9, 2**11, 2**13, 2**15]
gamma_range = [2**-23, 2**-21, 2**-19, 2**-17, 2**-15, 2**-13, 2**-11, 2**-9, 2**-7, 2**-5, 2**-3]
param_dict = dict(gamma=gamma_range, C=C_range)



# Initalise
cv = cb.cross_val.kfold(model=cb.model.SVM,                      
                                X=XTknn,                                 
                                Y=Y,                               
                                param_dict=param_dict,                   
                                folds=5,
                                n_mc=10)                                

# Run and plot
cv.run()  
cv.plot(metric='auc', ci=95, scale=1.3, color_beta=2, color_scaling='tanh')  # color_scaling='tanh','tanh+1' , 'linear', 'sq', 'sqrt'
# Out:
# Number of cores set to: 8
# Running ...
# 100%|██████████| 1210/1210 [01:08<00:00, 18.81it/s]
# Time taken: 1.15 minutes with 8 cores
# Done!
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1442">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6aaf1302-1a0d-4fda-99df-d07c52784b45" data-root-id="1441"></div>

# %% [markdown]
# ### 6. Get Model and Evaluate

# %%
# 6. Train, test and evaluate model

# Train model
model = cb.model.SVM(C=128, gamma=2**-17)
model.train(XTknn, Y)
model.test(XTknn)

# Evaluate 
model.evaluate(cutoffscore=0.5, plot_median=False)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2007">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="134f134d-874e-4212-a1f0-69fbb0203acd" data-root-id="2009"></div>

# %%
# Bootstrap evaluate
model.booteval(XTknn, Y, cutoffscore=0.5, bootnum=100)
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 18.17it/s]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2782">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="47ba1184-9c36-4082-8988-21faa0acb6c1" data-root-id="2784"></div>

# %% [markdown]
# ### 7. Save table

# %%
home = 'tables/'
file = 'SVM_MTBLS24_NH.xlsx'

model.save_table(home + file)
# Out:
# Done! Saved table as tables/SVM_MTBLS24_NH.xlsx
