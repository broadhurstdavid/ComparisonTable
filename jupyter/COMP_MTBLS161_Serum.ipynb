# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS161_Serum',
        'tables/PCR_MTBLS161_Serum',
        'tables/PCLR_MTBLS161_Serum',
        'tables/RF_MTBLS161_Serum',
        'tables/SVM_MTBLS161_Serum']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Serum   2.32e-06   0.94 (0.86, 1.0)   0.85 (0.74, 0.9)
# tables/PCR_MTBLS161_Serum   1.19e-05   0.91 (0.8, 0.99)   0.8 (0.59, 0.93)
# tables/PCLR_MTBLS161_Serum  1.12e-05  0.84 (0.73, 0.96)  0.85 (0.73, 0.95)
# tables/RF_MTBLS161_Serum    6.70e-05  0.87 (0.75, 0.97)  0.78 (0.66, 0.85)
# tables/SVM_MTBLS161_Serum   1.37e-06   0.95 (0.87, 1.0)   0.83 (0.73, 0.9)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Serum    0.85 (0.73, 0.9)  0.92 (0.73, 1.0)        0.76
# tables/PCR_MTBLS161_Serum    0.86 (0.7, 0.95)  0.79 (0.47, 1.0)        0.82
# tables/PCLR_MTBLS161_Serum  0.85 (0.71, 0.96)  0.92 (0.75, 1.0)        0.76
# tables/RF_MTBLS161_Serum    0.76 (0.62, 0.87)  0.92 (0.73, 1.0)        0.59
# tables/SVM_MTBLS161_Serum    0.81 (0.7, 0.89)  0.92 (0.76, 1.0)        0.71
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Serum   0.88 (0.77, 0.93)  0.55 (0.32, 0.69)
# tables/PCR_MTBLS161_Serum   0.83 (0.58, 0.94)   0.47 (0.2, 0.66)
# tables/PCLR_MTBLS161_Serum  0.88 (0.74, 0.96)     nan (nan, nan)
# tables/RF_MTBLS161_Serum     0.83 (0.71, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS161_Serum   0.86 (0.74, 0.93)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                            manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS161_Serum       0.01  0.85     0.72      0.78         0.7
# tables/PCR_MTBLS161_Serum       0.01  0.85     0.78       0.8         0.8
# tables/PCLR_MTBLS161_Serum      0.07  0.72     0.72      0.78         0.7
# tables/RF_MTBLS161_Serum        0.03  0.82     0.72      0.73         0.8
# tables/SVM_MTBLS161_Serum       0.01  0.89     0.78       0.8         0.8
#
#                            specificity F1score    R2
# method
# tables/PLS_MTBLS161_Serum         0.75    0.74  0.17
# tables/PCR_MTBLS161_Serum         0.75     0.8  0.24
# tables/PCLR_MTBLS161_Serum        0.75    0.74   nan
# tables/RF_MTBLS161_Serum          0.62    0.76   nan
# tables/SVM_MTBLS161_Serum         0.75     0.8   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Serum   2.32e-06   0.94 (0.86, 1.0)   0.85 (0.74, 0.9)
# tables/PCR_MTBLS161_Serum   1.19e-05   0.91 (0.8, 0.99)   0.8 (0.59, 0.93)
# tables/PCLR_MTBLS161_Serum  1.12e-05  0.84 (0.73, 0.96)  0.85 (0.73, 0.95)
# tables/RF_MTBLS161_Serum    6.70e-05  0.87 (0.75, 0.97)  0.78 (0.66, 0.85)
# tables/SVM_MTBLS161_Serum   1.37e-06   0.95 (0.87, 1.0)   0.83 (0.73, 0.9)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Serum    0.85 (0.73, 0.9)  0.92 (0.73, 1.0)        0.76
# tables/PCR_MTBLS161_Serum    0.86 (0.7, 0.95)  0.79 (0.47, 1.0)        0.82
# tables/PCLR_MTBLS161_Serum  0.85 (0.71, 0.96)  0.92 (0.75, 1.0)        0.76
# tables/RF_MTBLS161_Serum    0.76 (0.62, 0.87)  0.92 (0.73, 1.0)        0.59
# tables/SVM_MTBLS161_Serum    0.81 (0.7, 0.89)  0.92 (0.76, 1.0)        0.71
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Serum   0.88 (0.77, 0.93)  0.55 (0.32, 0.69)
# tables/PCR_MTBLS161_Serum   0.83 (0.58, 0.94)   0.47 (0.2, 0.66)
# tables/PCLR_MTBLS161_Serum  0.88 (0.74, 0.96)     nan (nan, nan)
# tables/RF_MTBLS161_Serum     0.83 (0.71, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS161_Serum   0.86 (0.74, 0.93)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                            manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS161_Serum   2.32e-06   0.94 (0.86, 1.0)   0.85 (0.74, 0.9)
# tables/PCR_MTBLS161_Serum   1.19e-05   0.91 (0.8, 0.99)   0.8 (0.59, 0.93)
# tables/PCLR_MTBLS161_Serum  1.12e-05  0.84 (0.73, 0.96)  0.85 (0.73, 0.95)
# tables/RF_MTBLS161_Serum    6.70e-05  0.87 (0.75, 0.97)  0.78 (0.66, 0.85)
# tables/SVM_MTBLS161_Serum   1.37e-06   0.95 (0.87, 1.0)   0.83 (0.73, 0.9)
#
#                                     precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS161_Serum    0.85 (0.73, 0.9)  0.92 (0.73, 1.0)        0.76
# tables/PCR_MTBLS161_Serum    0.86 (0.7, 0.95)  0.79 (0.47, 1.0)        0.82
# tables/PCLR_MTBLS161_Serum  0.85 (0.71, 0.96)  0.92 (0.75, 1.0)        0.76
# tables/RF_MTBLS161_Serum    0.76 (0.62, 0.87)  0.92 (0.73, 1.0)        0.59
# tables/SVM_MTBLS161_Serum    0.81 (0.7, 0.89)  0.92 (0.76, 1.0)        0.71
#
#                                       F1score                 R2
# method
# tables/PLS_MTBLS161_Serum   0.88 (0.77, 0.93)  0.55 (0.32, 0.69)
# tables/PCR_MTBLS161_Serum   0.83 (0.58, 0.94)   0.47 (0.2, 0.66)
# tables/PCLR_MTBLS161_Serum  0.88 (0.74, 0.96)     nan (nan, nan)
# tables/RF_MTBLS161_Serum     0.83 (0.71, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS161_Serum   0.86 (0.74, 0.93)     nan (nan, nan)
