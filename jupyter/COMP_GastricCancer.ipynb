# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_GastricCancer',
        'tables/PCR_GastricCancer',
        'tables/PCLR_GastricCancer',
        'tables/RF_GastricCancer',
        'tables/SVM_GastricCancer']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                           manw_pval                auc           accuracy  \
# method
# tables/PLS_GastricCancer   1.12e-10   0.99 (0.98, 1.0)  0.93 (0.88, 0.97)
# tables/PCR_GastricCancer   5.13e-09  0.95 (0.89, 0.98)  0.79 (0.72, 0.91)
# tables/PCLR_GastricCancer  2.97e-06   0.81 (0.72, 0.9)   0.81 (0.72, 0.9)
# tables/RF_GastricCancer    1.63e-07   0.87 (0.8, 0.95)  0.81 (0.74, 0.88)
# tables/SVM_GastricCancer   8.22e-11    1.0 (0.99, 1.0)   0.97 (0.4, 0.98)
#
#                                    precision        sensitivity specificity  \
# method
# tables/PLS_GastricCancer   0.91 (0.83, 0.95)   0.97 (0.88, 1.0)        0.89
# tables/PCR_GastricCancer   0.78 (0.67, 0.88)   0.83 (0.68, 1.0)        0.75
# tables/PCLR_GastricCancer  0.81 (0.63, 0.94)  0.83 (0.68, 0.95)        0.79
# tables/RF_GastricCancer    0.77 (0.67, 0.85)    0.9 (0.79, 1.0)        0.71
# tables/SVM_GastricCancer   0.97 (0.92, 0.97)    0.97 (0.0, 1.0)        0.96
#
#                                      F1score                 R2
# method
# tables/PLS_GastricCancer   0.94 (0.89, 0.97)  0.75 (0.64, 0.82)
# tables/PCR_GastricCancer   0.81 (0.69, 0.93)  0.57 (0.45, 0.67)
# tables/PCLR_GastricCancer  0.82 (0.71, 0.91)     nan (nan, nan)
# tables/RF_GastricCancer     0.83 (0.73, 0.9)     nan (nan, nan)
# tables/SVM_GastricCancer    0.97 (0.0, 0.98)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                           manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_GastricCancer   1.26e-04  0.96     0.84       0.8        0.92
# tables/PCR_GastricCancer   1.57e-04  0.95     0.84       0.8        0.92
# tables/PCLR_GastricCancer  2.17e-04  0.88     0.88      0.86        0.92
# tables/RF_GastricCancer        0.16  0.66     0.68      0.69        0.69
# tables/SVM_GastricCancer   1.57e-04  0.95     0.88      0.81         1.0
#
#                           specificity F1score    R2
# method
# tables/PLS_GastricCancer         0.75    0.86   0.6
# tables/PCR_GastricCancer         0.75    0.86  0.54
# tables/PCLR_GastricCancer        0.83    0.89   nan
# tables/RF_GastricCancer          0.67    0.69   nan
# tables/SVM_GastricCancer         0.75     0.9   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                           manw_pval                auc           accuracy  \
# method
# tables/PLS_GastricCancer   1.12e-10   0.99 (0.98, 1.0)  0.93 (0.88, 0.97)
# tables/PCR_GastricCancer   5.13e-09  0.95 (0.89, 0.98)  0.79 (0.72, 0.91)
# tables/PCLR_GastricCancer  2.97e-06   0.81 (0.72, 0.9)   0.81 (0.72, 0.9)
# tables/RF_GastricCancer    1.63e-07   0.87 (0.8, 0.95)  0.81 (0.74, 0.88)
# tables/SVM_GastricCancer   8.22e-11    1.0 (0.99, 1.0)   0.97 (0.4, 0.98)
#
#                                    precision        sensitivity specificity  \
# method
# tables/PLS_GastricCancer   0.91 (0.83, 0.95)   0.97 (0.88, 1.0)        0.89
# tables/PCR_GastricCancer   0.78 (0.67, 0.88)   0.83 (0.68, 1.0)        0.75
# tables/PCLR_GastricCancer  0.81 (0.63, 0.94)  0.83 (0.68, 0.95)        0.79
# tables/RF_GastricCancer    0.77 (0.67, 0.85)    0.9 (0.79, 1.0)        0.71
# tables/SVM_GastricCancer   0.97 (0.92, 0.97)    0.97 (0.0, 1.0)        0.96
#
#                                      F1score                 R2
# method
# tables/PLS_GastricCancer   0.94 (0.89, 0.97)  0.75 (0.64, 0.82)
# tables/PCR_GastricCancer   0.81 (0.69, 0.93)  0.57 (0.45, 0.67)
# tables/PCLR_GastricCancer  0.82 (0.71, 0.91)     nan (nan, nan)
# tables/RF_GastricCancer     0.83 (0.73, 0.9)     nan (nan, nan)
# tables/SVM_GastricCancer    0.97 (0.0, 0.98)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                           manw_pval                auc           accuracy  \
# method
# tables/PLS_GastricCancer   1.12e-10   0.99 (0.98, 1.0)  0.93 (0.88, 0.97)
# tables/PCR_GastricCancer   5.13e-09  0.95 (0.89, 0.98)  0.79 (0.72, 0.91)
# tables/PCLR_GastricCancer  2.97e-06   0.81 (0.72, 0.9)   0.81 (0.72, 0.9)
# tables/RF_GastricCancer    1.63e-07   0.87 (0.8, 0.95)  0.81 (0.74, 0.88)
# tables/SVM_GastricCancer   8.22e-11    1.0 (0.99, 1.0)   0.97 (0.4, 0.98)
#
#                                    precision        sensitivity specificity  \
# method
# tables/PLS_GastricCancer   0.91 (0.83, 0.95)   0.97 (0.88, 1.0)        0.89
# tables/PCR_GastricCancer   0.78 (0.67, 0.88)   0.83 (0.68, 1.0)        0.75
# tables/PCLR_GastricCancer  0.81 (0.63, 0.94)  0.83 (0.68, 0.95)        0.79
# tables/RF_GastricCancer    0.77 (0.67, 0.85)    0.9 (0.79, 1.0)        0.71
# tables/SVM_GastricCancer   0.97 (0.92, 0.97)    0.97 (0.0, 1.0)        0.96
#
#                                      F1score                 R2
# method
# tables/PLS_GastricCancer   0.94 (0.89, 0.97)  0.75 (0.64, 0.82)
# tables/PCR_GastricCancer   0.81 (0.69, 0.93)  0.57 (0.45, 0.67)
# tables/PCLR_GastricCancer  0.82 (0.71, 0.91)     nan (nan, nan)
# tables/RF_GastricCancer     0.83 (0.73, 0.9)     nan (nan, nan)
# tables/SVM_GastricCancer    0.97 (0.0, 0.98)     nan (nan, nan)
