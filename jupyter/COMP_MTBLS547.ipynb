# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS547',
        'tables/PCR_MTBLS547',
        'tables/PCLR_MTBLS547',
        'tables/RF_MTBLS547',
        'tables/SVM_MTBLS547']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547   8.97e-11    0.96 (0.9, 1.0)  0.87 (0.64, 0.96)
# tables/PCR_MTBLS547   1.27e-11   0.98 (0.95, 1.0)  0.91 (0.76, 0.97)
# tables/PCLR_MTBLS547  1.29e-08  0.85 (0.75, 0.92)  0.85 (0.62, 0.91)
# tables/RF_MTBLS547    2.37e-09  0.92 (0.84, 0.99)   0.81 (0.6, 0.93)
# tables/SVM_MTBLS547   2.17e-12     1.0 (1.0, 1.0)  0.99 (0.42, 0.99)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547    0.9 (0.79, 0.95)   0.81 (0.39, 1.0)        0.91
# tables/PCR_MTBLS547   0.91 (0.83, 0.95)   0.91 (0.57, 1.0)        0.91
# tables/PCLR_MTBLS547   0.84 (0.7, 0.96)  0.84 (0.29, 0.95)        0.86
# tables/RF_MTBLS547    0.83 (0.63, 0.91)   0.75 (0.31, 1.0)        0.86
# tables/SVM_MTBLS547   0.97 (0.93, 0.98)     1.0 (0.0, 1.0)        0.97
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS547   0.85 (0.54, 0.97)  0.65 (0.45, 0.76)
# tables/PCR_MTBLS547   0.91 (0.68, 0.96)  0.69 (0.59, 0.77)
# tables/PCLR_MTBLS547  0.84 (0.28, 0.92)     nan (nan, nan)
# tables/RF_MTBLS547    0.79 (0.42, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS547    0.98 (0.0, 0.99)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                      manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS547   2.75e-04  0.89      0.8      0.79        0.79
# tables/PCR_MTBLS547   4.44e-04  0.88      0.8      0.75        0.86
# tables/PCLR_MTBLS547      0.00   0.8      0.8      0.79        0.79
# tables/RF_MTBLS547    5.10e-04  0.88     0.73      0.69        0.79
# tables/SVM_MTBLS547   7.86e-06  0.98      0.9      0.82         1.0
#
#                      specificity F1score    R2
# method
# tables/PLS_MTBLS547         0.81    0.79  0.49
# tables/PCR_MTBLS547         0.75     0.8  0.44
# tables/PCLR_MTBLS547        0.81    0.79   nan
# tables/RF_MTBLS547          0.69    0.73   nan
# tables/SVM_MTBLS547         0.81     0.9   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547   8.97e-11    0.96 (0.9, 1.0)  0.87 (0.64, 0.96)
# tables/PCR_MTBLS547   1.27e-11   0.98 (0.95, 1.0)  0.91 (0.76, 0.97)
# tables/PCLR_MTBLS547  1.29e-08  0.85 (0.75, 0.92)  0.85 (0.62, 0.91)
# tables/RF_MTBLS547    2.37e-09  0.92 (0.84, 0.99)   0.81 (0.6, 0.93)
# tables/SVM_MTBLS547   2.17e-12     1.0 (1.0, 1.0)  0.99 (0.42, 0.99)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547    0.9 (0.79, 0.95)   0.81 (0.39, 1.0)        0.91
# tables/PCR_MTBLS547   0.91 (0.83, 0.95)   0.91 (0.57, 1.0)        0.91
# tables/PCLR_MTBLS547   0.84 (0.7, 0.96)  0.84 (0.29, 0.95)        0.86
# tables/RF_MTBLS547    0.83 (0.63, 0.91)   0.75 (0.31, 1.0)        0.86
# tables/SVM_MTBLS547   0.97 (0.93, 0.98)     1.0 (0.0, 1.0)        0.97
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS547   0.85 (0.54, 0.97)  0.65 (0.45, 0.76)
# tables/PCR_MTBLS547   0.91 (0.68, 0.96)  0.69 (0.59, 0.77)
# tables/PCLR_MTBLS547  0.84 (0.28, 0.92)     nan (nan, nan)
# tables/RF_MTBLS547    0.79 (0.42, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS547    0.98 (0.0, 0.99)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547   8.97e-11    0.96 (0.9, 1.0)  0.87 (0.64, 0.96)
# tables/PCR_MTBLS547   1.27e-11   0.98 (0.95, 1.0)  0.91 (0.76, 0.97)
# tables/PCLR_MTBLS547  1.29e-08  0.85 (0.75, 0.92)  0.85 (0.62, 0.91)
# tables/RF_MTBLS547    2.37e-09  0.92 (0.84, 0.99)   0.81 (0.6, 0.93)
# tables/SVM_MTBLS547   2.17e-12     1.0 (1.0, 1.0)  0.99 (0.42, 0.99)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547    0.9 (0.79, 0.95)   0.81 (0.39, 1.0)        0.91
# tables/PCR_MTBLS547   0.91 (0.83, 0.95)   0.91 (0.57, 1.0)        0.91
# tables/PCLR_MTBLS547   0.84 (0.7, 0.96)  0.84 (0.29, 0.95)        0.86
# tables/RF_MTBLS547    0.83 (0.63, 0.91)   0.75 (0.31, 1.0)        0.86
# tables/SVM_MTBLS547   0.97 (0.93, 0.98)     1.0 (0.0, 1.0)        0.97
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS547   0.85 (0.54, 0.97)  0.65 (0.45, 0.76)
# tables/PCR_MTBLS547   0.91 (0.68, 0.96)  0.69 (0.59, 0.77)
# tables/PCLR_MTBLS547  0.84 (0.28, 0.92)     nan (nan, nan)
# tables/RF_MTBLS547    0.79 (0.42, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS547    0.98 (0.0, 0.99)     nan (nan, nan)
