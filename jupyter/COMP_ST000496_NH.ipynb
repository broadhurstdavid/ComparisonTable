# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_ST000496_NH',
        'tables/PCR_ST000496_NH',
        'tables/PCLR_ST000496_NH',
        'tables/RF_ST000496_NH',
        'tables/SVM_ST000496_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000496_NH   1.21e-17    1.0 (0.99, 1.0)   0.98 (0.95, 1.0)
# tables/PCR_ST000496_NH   7.07e-18     1.0 (1.0, 1.0)   0.99 (0.96, 1.0)
# tables/PCLR_ST000496_NH  5.32e-20  0.96 (0.92, 0.99)   0.96 (0.4, 0.98)
# tables/RF_ST000496_NH    1.99e-07   0.8 (0.73, 0.87)  0.68 (0.59, 0.79)
# tables/SVM_ST000496_NH   1.63e-17   0.99 (0.98, 1.0)   0.98 (0.96, 1.0)
#
#                                  precision       sensitivity specificity  \
# method
# tables/PLS_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.89, 1.0)         1.0
# tables/PCR_ST000496_NH      1.0 (1.0, 1.0)  0.98 (0.93, 1.0)         1.0
# tables/PCLR_ST000496_NH  0.98 (0.95, 0.98)  0.94 (0.0, 0.98)        0.98
# tables/RF_ST000496_NH    0.64 (0.53, 0.74)  0.84 (0.66, 1.0)        0.52
# tables/SVM_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.91, 1.0)         1.0
#
#                                   F1score                 R2
# method
# tables/PLS_ST000496_NH   0.98 (0.94, 1.0)   0.8 (0.75, 0.85)
# tables/PCR_ST000496_NH   0.99 (0.96, 1.0)  0.84 (0.79, 0.88)
# tables/PCLR_ST000496_NH  0.96 (0.0, 0.98)     nan (nan, nan)
# tables/RF_ST000496_NH    0.72 (0.6, 0.85)     nan (nan, nan)
# tables/SVM_ST000496_NH   0.98 (0.95, 1.0)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000496_NH   1.21e-17    1.0 (0.99, 1.0)   0.98 (0.95, 1.0)
# tables/PCR_ST000496_NH   7.07e-18     1.0 (1.0, 1.0)   0.99 (0.96, 1.0)
# tables/PCLR_ST000496_NH  5.32e-20  0.96 (0.92, 0.99)   0.96 (0.4, 0.98)
# tables/RF_ST000496_NH    1.99e-07   0.8 (0.73, 0.87)  0.68 (0.59, 0.79)
# tables/SVM_ST000496_NH   1.63e-17   0.99 (0.98, 1.0)   0.98 (0.96, 1.0)
#
#                                  precision       sensitivity specificity  \
# method
# tables/PLS_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.89, 1.0)         1.0
# tables/PCR_ST000496_NH      1.0 (1.0, 1.0)  0.98 (0.93, 1.0)         1.0
# tables/PCLR_ST000496_NH  0.98 (0.95, 0.98)  0.94 (0.0, 0.98)        0.98
# tables/RF_ST000496_NH    0.64 (0.53, 0.74)  0.84 (0.66, 1.0)        0.52
# tables/SVM_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.91, 1.0)         1.0
#
#                                   F1score                 R2
# method
# tables/PLS_ST000496_NH   0.98 (0.94, 1.0)   0.8 (0.75, 0.85)
# tables/PCR_ST000496_NH   0.99 (0.96, 1.0)  0.84 (0.79, 0.88)
# tables/PCLR_ST000496_NH  0.96 (0.0, 0.98)     nan (nan, nan)
# tables/RF_ST000496_NH    0.72 (0.6, 0.85)     nan (nan, nan)
# tables/SVM_ST000496_NH   0.98 (0.95, 1.0)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_ST000496_NH   1.21e-17    1.0 (0.99, 1.0)   0.98 (0.95, 1.0)
# tables/PCR_ST000496_NH   7.07e-18     1.0 (1.0, 1.0)   0.99 (0.96, 1.0)
# tables/PCLR_ST000496_NH  5.32e-20  0.96 (0.92, 0.99)   0.96 (0.4, 0.98)
# tables/RF_ST000496_NH    1.99e-07   0.8 (0.73, 0.87)  0.68 (0.59, 0.79)
# tables/SVM_ST000496_NH   1.63e-17   0.99 (0.98, 1.0)   0.98 (0.96, 1.0)
#
#                                  precision       sensitivity specificity  \
# method
# tables/PLS_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.89, 1.0)         1.0
# tables/PCR_ST000496_NH      1.0 (1.0, 1.0)  0.98 (0.93, 1.0)         1.0
# tables/PCLR_ST000496_NH  0.98 (0.95, 0.98)  0.94 (0.0, 0.98)        0.98
# tables/RF_ST000496_NH    0.64 (0.53, 0.74)  0.84 (0.66, 1.0)        0.52
# tables/SVM_ST000496_NH      1.0 (1.0, 1.0)  0.96 (0.91, 1.0)         1.0
#
#                                   F1score                 R2
# method
# tables/PLS_ST000496_NH   0.98 (0.94, 1.0)   0.8 (0.75, 0.85)
# tables/PCR_ST000496_NH   0.99 (0.96, 1.0)  0.84 (0.79, 0.88)
# tables/PCLR_ST000496_NH  0.96 (0.0, 0.98)     nan (nan, nan)
# tables/RF_ST000496_NH    0.72 (0.6, 0.85)     nan (nan, nan)
# tables/SVM_ST000496_NH   0.98 (0.95, 1.0)     nan (nan, nan)
