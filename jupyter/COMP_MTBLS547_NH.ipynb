# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS547_NH',
        'tables/PCR_MTBLS547_NH',
        'tables/PCLR_MTBLS547_NH',
        'tables/RF_MTBLS547_NH',
        'tables/SVM_MTBLS547_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547_NH   2.05e-14  0.95 (0.91, 0.99)  0.87 (0.72, 0.94)
# tables/PCR_MTBLS547_NH   4.69e-15  0.96 (0.92, 0.99)  0.91 (0.76, 0.94)
# tables/PCLR_MTBLS547_NH  4.43e-11   0.84 (0.76, 0.9)   0.84 (0.76, 0.9)
# tables/RF_MTBLS547_NH    1.54e-17    1.0 (0.99, 1.0)   0.99 (0.96, 1.0)
# tables/SVM_MTBLS547_NH   2.44e-17     1.0 (1.0, 1.0)  0.99 (0.46, 0.99)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547_NH    0.85 (0.78, 0.9)   0.87 (0.56, 1.0)        0.86
# tables/PCR_MTBLS547_NH   0.88 (0.81, 0.91)   0.93 (0.62, 1.0)        0.88
# tables/PCLR_MTBLS547_NH    0.8 (0.7, 0.91)  0.87 (0.76, 0.95)         0.8
# tables/RF_MTBLS547_NH       1.0 (1.0, 1.0)   0.98 (0.92, 1.0)         1.0
# tables/SVM_MTBLS547_NH   0.98 (0.95, 0.98)     1.0 (0.0, 1.0)        0.98
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS547_NH   0.86 (0.67, 0.95)  0.62 (0.49, 0.74)
# tables/PCR_MTBLS547_NH   0.91 (0.71, 0.95)  0.63 (0.51, 0.71)
# tables/PCLR_MTBLS547_NH   0.83 (0.75, 0.9)     nan (nan, nan)
# tables/RF_MTBLS547_NH     0.99 (0.96, 1.0)     nan (nan, nan)
# tables/SVM_MTBLS547_NH    0.99 (0.0, 0.99)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547_NH   2.05e-14  0.95 (0.91, 0.99)  0.87 (0.72, 0.94)
# tables/PCR_MTBLS547_NH   4.69e-15  0.96 (0.92, 0.99)  0.91 (0.76, 0.94)
# tables/PCLR_MTBLS547_NH  4.43e-11   0.84 (0.76, 0.9)   0.84 (0.76, 0.9)
# tables/RF_MTBLS547_NH    1.54e-17    1.0 (0.99, 1.0)   0.99 (0.96, 1.0)
# tables/SVM_MTBLS547_NH   2.44e-17     1.0 (1.0, 1.0)  0.99 (0.46, 0.99)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547_NH    0.85 (0.78, 0.9)   0.87 (0.56, 1.0)        0.86
# tables/PCR_MTBLS547_NH   0.88 (0.81, 0.91)   0.93 (0.62, 1.0)        0.88
# tables/PCLR_MTBLS547_NH    0.8 (0.7, 0.91)  0.87 (0.76, 0.95)         0.8
# tables/RF_MTBLS547_NH       1.0 (1.0, 1.0)   0.98 (0.92, 1.0)         1.0
# tables/SVM_MTBLS547_NH   0.98 (0.95, 0.98)     1.0 (0.0, 1.0)        0.98
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS547_NH   0.86 (0.67, 0.95)  0.62 (0.49, 0.74)
# tables/PCR_MTBLS547_NH   0.91 (0.71, 0.95)  0.63 (0.51, 0.71)
# tables/PCLR_MTBLS547_NH   0.83 (0.75, 0.9)     nan (nan, nan)
# tables/RF_MTBLS547_NH     0.99 (0.96, 1.0)     nan (nan, nan)
# tables/SVM_MTBLS547_NH    0.99 (0.0, 0.99)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS547_NH   2.05e-14  0.95 (0.91, 0.99)  0.87 (0.72, 0.94)
# tables/PCR_MTBLS547_NH   4.69e-15  0.96 (0.92, 0.99)  0.91 (0.76, 0.94)
# tables/PCLR_MTBLS547_NH  4.43e-11   0.84 (0.76, 0.9)   0.84 (0.76, 0.9)
# tables/RF_MTBLS547_NH    1.54e-17    1.0 (0.99, 1.0)   0.99 (0.96, 1.0)
# tables/SVM_MTBLS547_NH   2.44e-17     1.0 (1.0, 1.0)  0.99 (0.46, 0.99)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS547_NH    0.85 (0.78, 0.9)   0.87 (0.56, 1.0)        0.86
# tables/PCR_MTBLS547_NH   0.88 (0.81, 0.91)   0.93 (0.62, 1.0)        0.88
# tables/PCLR_MTBLS547_NH    0.8 (0.7, 0.91)  0.87 (0.76, 0.95)         0.8
# tables/RF_MTBLS547_NH       1.0 (1.0, 1.0)   0.98 (0.92, 1.0)         1.0
# tables/SVM_MTBLS547_NH   0.98 (0.95, 0.98)     1.0 (0.0, 1.0)        0.98
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS547_NH   0.86 (0.67, 0.95)  0.62 (0.49, 0.74)
# tables/PCR_MTBLS547_NH   0.91 (0.71, 0.95)  0.63 (0.51, 0.71)
# tables/PCLR_MTBLS547_NH   0.83 (0.75, 0.9)     nan (nan, nan)
# tables/RF_MTBLS547_NH     0.99 (0.96, 1.0)     nan (nan, nan)
# tables/SVM_MTBLS547_NH    0.99 (0.0, 0.99)     nan (nan, nan)
