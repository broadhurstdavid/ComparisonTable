# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS24_NH',
        'tables/PCR_MTBLS24_NH',
        'tables/PCLR_MTBLS24_NH',
        'tables/RF_MTBLS24_NH',
        'tables/SVM_MTBLS24_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24_NH   4.11e-08   0.83 (0.75, 0.9)  0.76 (0.68, 0.86)
# tables/PCR_MTBLS24_NH   3.40e-07  0.81 (0.73, 0.88)  0.73 (0.65, 0.79)
# tables/PCLR_MTBLS24_NH  1.31e-04  0.67 (0.57, 0.74)  0.75 (0.66, 0.81)
# tables/RF_MTBLS24_NH    1.38e-09  0.86 (0.77, 0.94)  0.75 (0.69, 0.81)
# tables/SVM_MTBLS24_NH   6.22e-16   0.99 (0.97, 1.0)   0.92 (0.9, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS24_NH   0.79 (0.72, 0.87)   0.89 (0.77, 1.0)         0.5
# tables/PCR_MTBLS24_NH   0.73 (0.65, 0.81)   0.94 (0.88, 1.0)        0.26
# tables/PCLR_MTBLS24_NH  0.77 (0.68, 0.85)  0.89 (0.82, 0.95)        0.44
# tables/RF_MTBLS24_NH    0.73 (0.66, 0.81)    1.0 (0.94, 1.0)        0.24
# tables/SVM_MTBLS24_NH   0.92 (0.88, 0.95)   0.97 (0.94, 1.0)        0.82
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS24_NH   0.84 (0.76, 0.92)  0.23 (0.07, 0.32)
# tables/PCR_MTBLS24_NH   0.82 (0.76, 0.88)  0.23 (0.11, 0.35)
# tables/PCLR_MTBLS24_NH  0.83 (0.76, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24_NH     0.85 (0.8, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24_NH   0.95 (0.92, 0.97)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24_NH   4.11e-08   0.83 (0.75, 0.9)  0.76 (0.68, 0.86)
# tables/PCR_MTBLS24_NH   3.40e-07  0.81 (0.73, 0.88)  0.73 (0.65, 0.79)
# tables/PCLR_MTBLS24_NH  1.31e-04  0.67 (0.57, 0.74)  0.75 (0.66, 0.81)
# tables/RF_MTBLS24_NH    1.38e-09  0.86 (0.77, 0.94)  0.75 (0.69, 0.81)
# tables/SVM_MTBLS24_NH   6.22e-16   0.99 (0.97, 1.0)   0.92 (0.9, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS24_NH   0.79 (0.72, 0.87)   0.89 (0.77, 1.0)         0.5
# tables/PCR_MTBLS24_NH   0.73 (0.65, 0.81)   0.94 (0.88, 1.0)        0.26
# tables/PCLR_MTBLS24_NH  0.77 (0.68, 0.85)  0.89 (0.82, 0.95)        0.44
# tables/RF_MTBLS24_NH    0.73 (0.66, 0.81)    1.0 (0.94, 1.0)        0.24
# tables/SVM_MTBLS24_NH   0.92 (0.88, 0.95)   0.97 (0.94, 1.0)        0.82
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS24_NH   0.84 (0.76, 0.92)  0.23 (0.07, 0.32)
# tables/PCR_MTBLS24_NH   0.82 (0.76, 0.88)  0.23 (0.11, 0.35)
# tables/PCLR_MTBLS24_NH  0.83 (0.76, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24_NH     0.85 (0.8, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24_NH   0.95 (0.92, 0.97)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24_NH   4.11e-08   0.83 (0.75, 0.9)  0.76 (0.68, 0.86)
# tables/PCR_MTBLS24_NH   3.40e-07  0.81 (0.73, 0.88)  0.73 (0.65, 0.79)
# tables/PCLR_MTBLS24_NH  1.31e-04  0.67 (0.57, 0.74)  0.75 (0.66, 0.81)
# tables/RF_MTBLS24_NH    1.38e-09  0.86 (0.77, 0.94)  0.75 (0.69, 0.81)
# tables/SVM_MTBLS24_NH   6.22e-16   0.99 (0.97, 1.0)   0.92 (0.9, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS24_NH   0.79 (0.72, 0.87)   0.89 (0.77, 1.0)         0.5
# tables/PCR_MTBLS24_NH   0.73 (0.65, 0.81)   0.94 (0.88, 1.0)        0.26
# tables/PCLR_MTBLS24_NH  0.77 (0.68, 0.85)  0.89 (0.82, 0.95)        0.44
# tables/RF_MTBLS24_NH    0.73 (0.66, 0.81)    1.0 (0.94, 1.0)        0.24
# tables/SVM_MTBLS24_NH   0.92 (0.88, 0.95)   0.97 (0.94, 1.0)        0.82
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS24_NH   0.84 (0.76, 0.92)  0.23 (0.07, 0.32)
# tables/PCR_MTBLS24_NH   0.82 (0.76, 0.88)  0.23 (0.11, 0.35)
# tables/PCLR_MTBLS24_NH  0.83 (0.76, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24_NH     0.85 (0.8, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24_NH   0.95 (0.92, 0.97)     nan (nan, nan)
