# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS93',
        'tables/PCR_MTBLS93',
        'tables/PCLR_MTBLS93',
        'tables/RF_MTBLS93',
        'tables/SVM_MTBLS93']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93   2.18e-217  0.97 (0.97, 0.98)  0.93 (0.91, 0.94)
# tables/PCR_MTBLS93   1.36e-161  0.91 (0.89, 0.92)  0.83 (0.81, 0.85)
# tables/PCLR_MTBLS93  5.98e-229   0.92 (0.9, 0.93)   0.92 (0.9, 0.93)
# tables/RF_MTBLS93    7.54e-200  0.95 (0.95, 0.96)  0.89 (0.87, 0.89)
# tables/SVM_MTBLS93   5.33e-193  0.95 (0.93, 0.96)  0.87 (0.83, 0.89)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93   0.94 (0.94, 0.95)   0.93 (0.9, 0.94)        0.93
# tables/PCR_MTBLS93   0.84 (0.82, 0.86)   0.87 (0.83, 0.9)        0.79
# tables/PCLR_MTBLS93  0.93 (0.91, 0.95)  0.93 (0.91, 0.94)        0.91
# tables/RF_MTBLS93    0.87 (0.85, 0.88)  0.94 (0.92, 0.96)        0.81
# tables/SVM_MTBLS93   0.93 (0.92, 0.94)  0.84 (0.77, 0.87)        0.92
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS93   0.94 (0.92, 0.94)  0.67 (0.65, 0.69)
# tables/PCR_MTBLS93   0.85 (0.83, 0.87)  0.46 (0.43, 0.49)
# tables/PCLR_MTBLS93  0.93 (0.92, 0.94)     nan (nan, nan)
# tables/RF_MTBLS93     0.9 (0.89, 0.91)     nan (nan, nan)
# tables/SVM_MTBLS93    0.88 (0.84, 0.9)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                     manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS93   3.57e-86  0.95     0.89      0.92        0.89
# tables/PCR_MTBLS93   8.10e-61  0.88      0.8      0.81        0.84
# tables/PCLR_MTBLS93  2.39e-84  0.89     0.89      0.91        0.89
# tables/RF_MTBLS93    1.40e-69  0.91     0.81      0.82        0.86
# tables/SVM_MTBLS93   1.91e-79  0.93     0.85       0.9        0.82
#
#                     specificity F1score    R2
# method
# tables/PLS_MTBLS93          0.9    0.91  0.57
# tables/PCR_MTBLS93         0.74    0.83  0.36
# tables/PCLR_MTBLS93        0.88     0.9   nan
# tables/RF_MTBLS93          0.76    0.84   nan
# tables/SVM_MTBLS93         0.88    0.86   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93   2.18e-217  0.97 (0.97, 0.98)  0.93 (0.91, 0.94)
# tables/PCR_MTBLS93   1.36e-161  0.91 (0.89, 0.92)  0.83 (0.81, 0.85)
# tables/PCLR_MTBLS93  5.98e-229   0.92 (0.9, 0.93)   0.92 (0.9, 0.93)
# tables/RF_MTBLS93    7.54e-200  0.95 (0.95, 0.96)  0.89 (0.87, 0.89)
# tables/SVM_MTBLS93   5.33e-193  0.95 (0.93, 0.96)  0.87 (0.83, 0.89)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93   0.94 (0.94, 0.95)   0.93 (0.9, 0.94)        0.93
# tables/PCR_MTBLS93   0.84 (0.82, 0.86)   0.87 (0.83, 0.9)        0.79
# tables/PCLR_MTBLS93  0.93 (0.91, 0.95)  0.93 (0.91, 0.94)        0.91
# tables/RF_MTBLS93    0.87 (0.85, 0.88)  0.94 (0.92, 0.96)        0.81
# tables/SVM_MTBLS93   0.93 (0.92, 0.94)  0.84 (0.77, 0.87)        0.92
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS93   0.94 (0.92, 0.94)  0.67 (0.65, 0.69)
# tables/PCR_MTBLS93   0.85 (0.83, 0.87)  0.46 (0.43, 0.49)
# tables/PCLR_MTBLS93  0.93 (0.92, 0.94)     nan (nan, nan)
# tables/RF_MTBLS93     0.9 (0.89, 0.91)     nan (nan, nan)
# tables/SVM_MTBLS93    0.88 (0.84, 0.9)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93   2.18e-217  0.97 (0.97, 0.98)  0.93 (0.91, 0.94)
# tables/PCR_MTBLS93   1.36e-161  0.91 (0.89, 0.92)  0.83 (0.81, 0.85)
# tables/PCLR_MTBLS93  5.98e-229   0.92 (0.9, 0.93)   0.92 (0.9, 0.93)
# tables/RF_MTBLS93    7.54e-200  0.95 (0.95, 0.96)  0.89 (0.87, 0.89)
# tables/SVM_MTBLS93   5.33e-193  0.95 (0.93, 0.96)  0.87 (0.83, 0.89)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93   0.94 (0.94, 0.95)   0.93 (0.9, 0.94)        0.93
# tables/PCR_MTBLS93   0.84 (0.82, 0.86)   0.87 (0.83, 0.9)        0.79
# tables/PCLR_MTBLS93  0.93 (0.91, 0.95)  0.93 (0.91, 0.94)        0.91
# tables/RF_MTBLS93    0.87 (0.85, 0.88)  0.94 (0.92, 0.96)        0.81
# tables/SVM_MTBLS93   0.93 (0.92, 0.94)  0.84 (0.77, 0.87)        0.92
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS93   0.94 (0.92, 0.94)  0.67 (0.65, 0.69)
# tables/PCR_MTBLS93   0.85 (0.83, 0.87)  0.46 (0.43, 0.49)
# tables/PCLR_MTBLS93  0.93 (0.92, 0.94)     nan (nan, nan)
# tables/RF_MTBLS93     0.9 (0.89, 0.91)     nan (nan, nan)
# tables/SVM_MTBLS93    0.88 (0.84, 0.9)     nan (nan, nan)
