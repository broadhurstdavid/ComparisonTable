# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS92',
        'tables/PCR_MTBLS92',
        'tables/PCLR_MTBLS92',
        'tables/RF_MTBLS92',
        'tables/SVM_MTBLS92']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92   1.45e-11  0.73 (0.67, 0.78)  0.69 (0.65, 0.74)
# tables/PCR_MTBLS92   1.12e-08  0.69 (0.64, 0.75)  0.66 (0.61, 0.71)
# tables/PCLR_MTBLS92  2.21e-07   0.65 (0.59, 0.7)   0.67 (0.6, 0.71)
# tables/RF_MTBLS92    2.28e-14  0.75 (0.69, 0.81)  0.71 (0.64, 0.75)
# tables/SVM_MTBLS92   7.63e-13  0.74 (0.68, 0.79)  0.61 (0.57, 0.66)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92   0.61 (0.53, 0.68)  0.55 (0.45, 0.67)        0.77
# tables/PCR_MTBLS92   0.56 (0.48, 0.64)  0.55 (0.44, 0.69)        0.72
# tables/PCLR_MTBLS92  0.57 (0.49, 0.65)  0.55 (0.48, 0.65)        0.74
# tables/RF_MTBLS92     0.64 (0.55, 0.7)  0.55 (0.46, 0.67)         0.8
# tables/SVM_MTBLS92      nan (nan, nan)     0.0 (0.0, 0.0)         1.0
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS92   0.57 (0.49, 0.67)   0.14 (0.07, 0.2)
# tables/PCR_MTBLS92   0.56 (0.47, 0.66)  0.11 (0.04, 0.17)
# tables/PCLR_MTBLS92  0.56 (0.49, 0.64)     nan (nan, nan)
# tables/RF_MTBLS92    0.59 (0.51, 0.67)     nan (nan, nan)
# tables/SVM_MTBLS92      0.0 (0.0, 0.0)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                     manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS92   8.48e-04  0.67     0.65      0.57        0.47
# tables/PCR_MTBLS92       0.01  0.64     0.63      0.53        0.47
# tables/PCLR_MTBLS92      0.02   0.6     0.63      0.53        0.47
# tables/RF_MTBLS92    8.77e-05   0.7     0.67      0.59        0.51
# tables/SVM_MTBLS92   1.02e-04   0.7     0.61       nan         0.0
#
#                     specificity F1score    R2
# method
# tables/PLS_MTBLS92         0.77    0.52  0.08
# tables/PCR_MTBLS92         0.73     0.5  0.06
# tables/PCLR_MTBLS92        0.73     0.5   nan
# tables/RF_MTBLS92          0.77    0.55   nan
# tables/SVM_MTBLS92          1.0     0.0   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92   1.45e-11  0.73 (0.67, 0.78)  0.69 (0.65, 0.74)
# tables/PCR_MTBLS92   1.12e-08  0.69 (0.64, 0.75)  0.66 (0.61, 0.71)
# tables/PCLR_MTBLS92  2.21e-07   0.65 (0.59, 0.7)   0.67 (0.6, 0.71)
# tables/RF_MTBLS92    2.28e-14  0.75 (0.69, 0.81)  0.71 (0.64, 0.75)
# tables/SVM_MTBLS92   7.63e-13  0.74 (0.68, 0.79)  0.61 (0.57, 0.66)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92   0.61 (0.53, 0.68)  0.55 (0.45, 0.67)        0.77
# tables/PCR_MTBLS92   0.56 (0.48, 0.64)  0.55 (0.44, 0.69)        0.72
# tables/PCLR_MTBLS92  0.57 (0.49, 0.65)  0.55 (0.48, 0.65)        0.74
# tables/RF_MTBLS92     0.64 (0.55, 0.7)  0.55 (0.46, 0.67)         0.8
# tables/SVM_MTBLS92      nan (nan, nan)     0.0 (0.0, 0.0)         1.0
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS92   0.57 (0.49, 0.67)   0.14 (0.07, 0.2)
# tables/PCR_MTBLS92   0.56 (0.47, 0.66)  0.11 (0.04, 0.17)
# tables/PCLR_MTBLS92  0.56 (0.49, 0.64)     nan (nan, nan)
# tables/RF_MTBLS92    0.59 (0.51, 0.67)     nan (nan, nan)
# tables/SVM_MTBLS92      0.0 (0.0, 0.0)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92   1.45e-11  0.73 (0.67, 0.78)  0.69 (0.65, 0.74)
# tables/PCR_MTBLS92   1.12e-08  0.69 (0.64, 0.75)  0.66 (0.61, 0.71)
# tables/PCLR_MTBLS92  2.21e-07   0.65 (0.59, 0.7)   0.67 (0.6, 0.71)
# tables/RF_MTBLS92    2.28e-14  0.75 (0.69, 0.81)  0.71 (0.64, 0.75)
# tables/SVM_MTBLS92   7.63e-13  0.74 (0.68, 0.79)  0.61 (0.57, 0.66)
#
#                              precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92   0.61 (0.53, 0.68)  0.55 (0.45, 0.67)        0.77
# tables/PCR_MTBLS92   0.56 (0.48, 0.64)  0.55 (0.44, 0.69)        0.72
# tables/PCLR_MTBLS92  0.57 (0.49, 0.65)  0.55 (0.48, 0.65)        0.74
# tables/RF_MTBLS92     0.64 (0.55, 0.7)  0.55 (0.46, 0.67)         0.8
# tables/SVM_MTBLS92      nan (nan, nan)     0.0 (0.0, 0.0)         1.0
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS92   0.57 (0.49, 0.67)   0.14 (0.07, 0.2)
# tables/PCR_MTBLS92   0.56 (0.47, 0.66)  0.11 (0.04, 0.17)
# tables/PCLR_MTBLS92  0.56 (0.49, 0.64)     nan (nan, nan)
# tables/RF_MTBLS92    0.59 (0.51, 0.67)     nan (nan, nan)
# tables/SVM_MTBLS92      0.0 (0.0, 0.0)     nan (nan, nan)
