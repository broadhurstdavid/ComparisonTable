# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS404',
        'tables/PCR_MTBLS404',
        'tables/PCLR_MTBLS404',
        'tables/RF_MTBLS404',
        'tables/SVM_MTBLS404']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404   1.01e-21   0.99 (0.98, 1.0)  0.96 (0.89, 0.98)
# tables/PCR_MTBLS404   8.88e-20  0.97 (0.93, 0.99)  0.89 (0.75, 0.96)
# tables/PCLR_MTBLS404  1.20e-20  0.91 (0.86, 0.95)  0.91 (0.86, 0.95)
# tables/RF_MTBLS404    3.34e-20  0.97 (0.95, 0.99)  0.91 (0.85, 0.93)
# tables/SVM_MTBLS404   6.66e-22    1.0 (0.99, 1.0)  0.95 (0.88, 0.98)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404   0.95 (0.91, 0.96)   0.99 (0.85, 1.0)        0.93
# tables/PCR_MTBLS404   0.92 (0.87, 0.96)   0.87 (0.6, 0.99)        0.91
# tables/PCLR_MTBLS404  0.93 (0.86, 0.97)  0.91 (0.82, 0.97)        0.91
# tables/RF_MTBLS404    0.89 (0.84, 0.91)  0.94 (0.84, 0.99)        0.86
# tables/SVM_MTBLS404   0.96 (0.93, 0.97)   0.94 (0.82, 1.0)        0.95
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS404   0.97 (0.88, 0.98)  0.76 (0.71, 0.81)
# tables/PCR_MTBLS404    0.9 (0.72, 0.97)  0.67 (0.57, 0.75)
# tables/PCLR_MTBLS404  0.92 (0.86, 0.95)     nan (nan, nan)
# tables/RF_MTBLS404    0.92 (0.86, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS404   0.95 (0.89, 0.99)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                      manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS404   9.83e-07  0.88     0.82      0.86        0.81
# tables/PCR_MTBLS404   7.36e-06  0.85     0.79      0.83        0.77
# tables/PCLR_MTBLS404  2.37e-05  0.79     0.79      0.83        0.77
# tables/RF_MTBLS404        0.01   0.7     0.68      0.71        0.71
# tables/SVM_MTBLS404   8.58e-06  0.85     0.79      0.85        0.74
#
#                      specificity F1score    R2
# method
# tables/PLS_MTBLS404         0.84    0.83  0.24
# tables/PCR_MTBLS404          0.8     0.8  0.21
# tables/PCLR_MTBLS404         0.8     0.8   nan
# tables/RF_MTBLS404          0.64    0.71   nan
# tables/SVM_MTBLS404         0.84    0.79   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404   1.01e-21   0.99 (0.98, 1.0)  0.96 (0.89, 0.98)
# tables/PCR_MTBLS404   8.88e-20  0.97 (0.93, 0.99)  0.89 (0.75, 0.96)
# tables/PCLR_MTBLS404  1.20e-20  0.91 (0.86, 0.95)  0.91 (0.86, 0.95)
# tables/RF_MTBLS404    3.34e-20  0.97 (0.95, 0.99)  0.91 (0.85, 0.93)
# tables/SVM_MTBLS404   6.66e-22    1.0 (0.99, 1.0)  0.95 (0.88, 0.98)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404   0.95 (0.91, 0.96)   0.99 (0.85, 1.0)        0.93
# tables/PCR_MTBLS404   0.92 (0.87, 0.96)   0.87 (0.6, 0.99)        0.91
# tables/PCLR_MTBLS404  0.93 (0.86, 0.97)  0.91 (0.82, 0.97)        0.91
# tables/RF_MTBLS404    0.89 (0.84, 0.91)  0.94 (0.84, 0.99)        0.86
# tables/SVM_MTBLS404   0.96 (0.93, 0.97)   0.94 (0.82, 1.0)        0.95
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS404   0.97 (0.88, 0.98)  0.76 (0.71, 0.81)
# tables/PCR_MTBLS404    0.9 (0.72, 0.97)  0.67 (0.57, 0.75)
# tables/PCLR_MTBLS404  0.92 (0.86, 0.95)     nan (nan, nan)
# tables/RF_MTBLS404    0.92 (0.86, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS404   0.95 (0.89, 0.99)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                      manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404   1.01e-21   0.99 (0.98, 1.0)  0.96 (0.89, 0.98)
# tables/PCR_MTBLS404   8.88e-20  0.97 (0.93, 0.99)  0.89 (0.75, 0.96)
# tables/PCLR_MTBLS404  1.20e-20  0.91 (0.86, 0.95)  0.91 (0.86, 0.95)
# tables/RF_MTBLS404    3.34e-20  0.97 (0.95, 0.99)  0.91 (0.85, 0.93)
# tables/SVM_MTBLS404   6.66e-22    1.0 (0.99, 1.0)  0.95 (0.88, 0.98)
#
#                               precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404   0.95 (0.91, 0.96)   0.99 (0.85, 1.0)        0.93
# tables/PCR_MTBLS404   0.92 (0.87, 0.96)   0.87 (0.6, 0.99)        0.91
# tables/PCLR_MTBLS404  0.93 (0.86, 0.97)  0.91 (0.82, 0.97)        0.91
# tables/RF_MTBLS404    0.89 (0.84, 0.91)  0.94 (0.84, 0.99)        0.86
# tables/SVM_MTBLS404   0.96 (0.93, 0.97)   0.94 (0.82, 1.0)        0.95
#
#                                 F1score                 R2
# method
# tables/PLS_MTBLS404   0.97 (0.88, 0.98)  0.76 (0.71, 0.81)
# tables/PCR_MTBLS404    0.9 (0.72, 0.97)  0.67 (0.57, 0.75)
# tables/PCLR_MTBLS404  0.92 (0.86, 0.95)     nan (nan, nan)
# tables/RF_MTBLS404    0.92 (0.86, 0.94)     nan (nan, nan)
# tables/SVM_MTBLS404   0.95 (0.89, 0.99)     nan (nan, nan)
