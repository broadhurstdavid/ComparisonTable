# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS24',
        'tables/PCR_MTBLS24',
        'tables/PCLR_MTBLS24',
        'tables/RF_MTBLS24',
        'tables/SVM_MTBLS24']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24   1.54e-07  0.88 (0.78, 0.95)  0.76 (0.68, 0.82)
# tables/PCR_MTBLS24   3.66e-05   0.8 (0.67, 0.91)  0.73 (0.63, 0.82)
# tables/PCLR_MTBLS24      0.00  0.66 (0.54, 0.73)  0.74 (0.64, 0.81)
# tables/RF_MTBLS24    3.07e-09  0.93 (0.88, 0.98)  0.76 (0.66, 0.82)
# tables/SVM_MTBLS24   3.04e-09  0.93 (0.87, 0.98)   0.8 (0.73, 0.86)
#
#                              precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS24   0.78 (0.68, 0.85)   0.9 (0.8, 0.98)        0.46
# tables/PCR_MTBLS24   0.74 (0.64, 0.82)  0.92 (0.81, 1.0)        0.33
# tables/PCLR_MTBLS24  0.76 (0.64, 0.84)  0.9 (0.81, 0.96)        0.42
# tables/RF_MTBLS24    0.75 (0.64, 0.83)   0.96 (0.9, 1.0)        0.33
# tables/SVM_MTBLS24   0.79 (0.71, 0.87)  0.96 (0.87, 1.0)        0.46
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS24   0.83 (0.76, 0.89)  0.34 (0.15, 0.45)
# tables/PCR_MTBLS24   0.82 (0.74, 0.89)   0.2 (0.01, 0.32)
# tables/PCLR_MTBLS24  0.83 (0.73, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24    0.84 (0.76, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24   0.86 (0.81, 0.92)     nan (nan, nan)

# %%
# 4. Test Table

train = cb.utils.load_comparisonXL(file, 'test')
display(train)
# Out:
#                     manw_pval   auc accuracy precision sensitivity  \
# method
# tables/PLS_MTBLS24       0.02  0.77     0.69      0.73        0.86
# tables/PCR_MTBLS24       0.03  0.75     0.66      0.72        0.82
# tables/PCLR_MTBLS24      0.41  0.55     0.69      0.71        0.91
# tables/RF_MTBLS24        0.00  0.84     0.72      0.72        0.95
# tables/SVM_MTBLS24       0.02  0.76     0.72      0.72        0.95
#
#                     specificity F1score    R2
# method
# tables/PLS_MTBLS24          0.3    0.79  0.09
# tables/PCR_MTBLS24          0.3    0.77  0.13
# tables/PCLR_MTBLS24         0.2     0.8   nan
# tables/RF_MTBLS24           0.2    0.82   nan
# tables/SVM_MTBLS24          0.2    0.82   nan

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24   1.54e-07  0.88 (0.78, 0.95)  0.76 (0.68, 0.82)
# tables/PCR_MTBLS24   3.66e-05   0.8 (0.67, 0.91)  0.73 (0.63, 0.82)
# tables/PCLR_MTBLS24      0.00  0.66 (0.54, 0.73)  0.74 (0.64, 0.81)
# tables/RF_MTBLS24    3.07e-09  0.93 (0.88, 0.98)  0.76 (0.66, 0.82)
# tables/SVM_MTBLS24   3.04e-09  0.93 (0.87, 0.98)   0.8 (0.73, 0.86)
#
#                              precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS24   0.78 (0.68, 0.85)   0.9 (0.8, 0.98)        0.46
# tables/PCR_MTBLS24   0.74 (0.64, 0.82)  0.92 (0.81, 1.0)        0.33
# tables/PCLR_MTBLS24  0.76 (0.64, 0.84)  0.9 (0.81, 0.96)        0.42
# tables/RF_MTBLS24    0.75 (0.64, 0.83)   0.96 (0.9, 1.0)        0.33
# tables/SVM_MTBLS24   0.79 (0.71, 0.87)  0.96 (0.87, 1.0)        0.46
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS24   0.83 (0.76, 0.89)  0.34 (0.15, 0.45)
# tables/PCR_MTBLS24   0.82 (0.74, 0.89)   0.2 (0.01, 0.32)
# tables/PCLR_MTBLS24  0.83 (0.73, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24    0.84 (0.76, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24   0.86 (0.81, 0.92)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                     manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS24   1.54e-07  0.88 (0.78, 0.95)  0.76 (0.68, 0.82)
# tables/PCR_MTBLS24   3.66e-05   0.8 (0.67, 0.91)  0.73 (0.63, 0.82)
# tables/PCLR_MTBLS24      0.00  0.66 (0.54, 0.73)  0.74 (0.64, 0.81)
# tables/RF_MTBLS24    3.07e-09  0.93 (0.88, 0.98)  0.76 (0.66, 0.82)
# tables/SVM_MTBLS24   3.04e-09  0.93 (0.87, 0.98)   0.8 (0.73, 0.86)
#
#                              precision       sensitivity specificity  \
# method
# tables/PLS_MTBLS24   0.78 (0.68, 0.85)   0.9 (0.8, 0.98)        0.46
# tables/PCR_MTBLS24   0.74 (0.64, 0.82)  0.92 (0.81, 1.0)        0.33
# tables/PCLR_MTBLS24  0.76 (0.64, 0.84)  0.9 (0.81, 0.96)        0.42
# tables/RF_MTBLS24    0.75 (0.64, 0.83)   0.96 (0.9, 1.0)        0.33
# tables/SVM_MTBLS24   0.79 (0.71, 0.87)  0.96 (0.87, 1.0)        0.46
#
#                                F1score                 R2
# method
# tables/PLS_MTBLS24   0.83 (0.76, 0.89)  0.34 (0.15, 0.45)
# tables/PCR_MTBLS24   0.82 (0.74, 0.89)   0.2 (0.01, 0.32)
# tables/PCLR_MTBLS24  0.83 (0.73, 0.88)     nan (nan, nan)
# tables/RF_MTBLS24    0.84 (0.76, 0.89)     nan (nan, nan)
# tables/SVM_MTBLS24   0.86 (0.81, 0.92)     nan (nan, nan)
