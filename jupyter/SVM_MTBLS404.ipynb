# %% [markdown]
# ## SVM

# %% [markdown]
# ----

# %% [markdown]
# ### 1. Import Modules

# %%
import numpy as np
import pandas as pd
import cimcb as cb
from sklearn.model_selection import train_test_split

print('All packages successfully loaded')
# Out:
# Using TensorFlow backend.
# All packages successfully loaded

# %% [markdown]
# ### 2. Load data and peak sheet

# %%
home = 'data/' 
file = 'MTBLS404.xlsx' 

DataTable,PeakTable = cb.utils.load_dataXL(home + file, DataSheet='Data', PeakSheet='Peak')
# Out:
# Loadings PeakFile: Peak
# Loadings DataFile: Data
# Data Table & Peak Table is suitable.
# TOTAL SAMPLES: 184 TOTAL PEAKS: 120
# Done!

# %% [markdown]
# ### 3. Extract X & Y

# %%
peaklist = PeakTable['Name']
DataTable2 = DataTable[(DataTable['Class']==0) | (DataTable['Class']==1)]
Y = DataTable2['Class'].values

# %% [markdown]
# ### 4. Hyperparameters optimisation

# %%
# Set seed
seed=50

# Split DataTable2 and Y into train and test (with stratification
DataTrain, DataTest, Ytrain, Ytest = train_test_split(DataTable2, Y, test_size=0.30, stratify=Y, random_state=seed)

# Extract and scale the metabolite data from the DataTable
peaklist = PeakTable['Name']                           
XT = DataTrain[peaklist]                                    
XTlog = np.log(XT)                                          
XTscale = cb.utils.scale(XTlog, method='auto')              
XTknn = cb.utils.knnimpute(XTscale, k=3)                                      
                                         
# param_dict
C_range = [2**-5, 2**-3, 2**-1, 2**1, 2**3, 2**5, 2**7, 2**9, 2**11, 2**13, 2**15]
gamma_range = [2**-15, 2**-13, 2**-11, 2**-9, 2**-7, 2**-5, 2**-3, 2**-1, 2**1, 2**3]
param_dict = dict(gamma=gamma_range, C=C_range)



# Initalise
cv = cb.cross_val.kfold(model=cb.model.SVM,                      
                                X=XTknn,                                 
                                Y=Ytrain,                               
                                param_dict=param_dict,                   
                                folds=5,
                                n_mc=50)                                

# Run and plot
cv.run()  
cv.plot(metric='r2q2', ci=95, scale=1.5)
# Out:
# Number of cores set to: 8
# Running ...
# 100%|██████████| 1100/1100 [00:28<00:00, 39.06it/s]
# Time taken: 0.47 minutes with 8 cores
# Done!
# metric changed from 'r2q2' to 'auc' as the model is non-parametric.
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="32968">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="23921514-cad8-42da-bb21-1c81599d02fc" data-root-id="32967"></div>

# %% [markdown]
# ### 6. Get Model and Evaluate

# %%
# 6. Train, test and evaluate model

# Train model
model = cb.model.SVM(C=2**7, gamma=2**-15)
model.train(XTknn, Ytrain)

# Get X, Y
mu, sigma  = cb.utils.scale(XTlog, return_mu_sigma=True) 
peaklist = PeakTable.Name 
XV = DataTest[peaklist].values
XVlog = np.log(XV)
XVscale  = cb.utils.scale(XVlog, method='auto', mu=mu, sigma=sigma)
XVknn = cb.utils.knnimpute(XVscale, k=3)
YVpred = model.test(XVknn)

# Evaluate Ypred against Ytest
evals = [Ytest, YVpred] 
model.evaluate(evals, cutoffscore=0.5, plot_median=False) 

print("AUC Train: {}".format(model.table['auc'][0][0]))
print("AUC Test: {}".format(model.table['auc'][1][0]))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="34932">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="2aa37003-9110-4331-b15b-1cada4c61315" data-root-id="34934"></div>
# AUC Train: 1.0 (0.99, 1.0)
# AUC Test: 0.85

# %%
# Get X
X = DataTable2[peaklist]                                    
Xlog = np.log(X)                                          
Xscale = cb.utils.scale(Xlog, method='auto')              
Xknn = cb.utils.knnimpute(Xscale, k=3)    

# Bootstrap evaluate
model.booteval(Xknn, Y, cutoffscore=0.5, bootnum=100)
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 27.97it/s]
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37132">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b6652a97-58a1-4664-b5de-dcef376c98a7" data-root-id="37134"></div>

# %% [markdown]
# ### 7. Save table

# %%
home = 'tables/'
file = 'SVM_MTBLS404.xlsx'

model.save_table(home + file)
# Out:
# Done! Saved table as tables/SVM_MTBLS404.xlsx
