# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS93_NH',
        'tables/PCR_MTBLS93_NH',
        'tables/PCLR_MTBLS93_NH',
        'tables/RF_MTBLS93_NH',
        'tables/SVM_MTBLS93_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93_NH   6.31e-306  0.97 (0.97, 0.98)   0.92 (0.9, 0.93)
# tables/PCR_MTBLS93_NH   1.74e-304  0.97 (0.96, 0.98)   0.92 (0.9, 0.93)
# tables/PCLR_MTBLS93_NH   0.00e+00  0.93 (0.92, 0.94)  0.94 (0.93, 0.95)
# tables/RF_MTBLS93_NH    4.76e-275  0.95 (0.94, 0.95)  0.87 (0.85, 0.88)
# tables/SVM_MTBLS93_NH    0.00e+00  0.98 (0.98, 0.99)  0.95 (0.94, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93_NH   0.94 (0.93, 0.94)   0.92 (0.9, 0.95)        0.92
# tables/PCR_MTBLS93_NH   0.93 (0.93, 0.94)   0.93 (0.9, 0.95)        0.91
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)  0.95 (0.93, 0.96)        0.92
# tables/RF_MTBLS93_NH    0.85 (0.84, 0.86)  0.93 (0.91, 0.95)        0.78
# tables/SVM_MTBLS93_NH   0.95 (0.95, 0.96)  0.95 (0.94, 0.97)        0.94
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS93_NH   0.93 (0.91, 0.94)  0.65 (0.63, 0.68)
# tables/PCR_MTBLS93_NH   0.93 (0.92, 0.94)  0.65 (0.63, 0.68)
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)     nan (nan, nan)
# tables/RF_MTBLS93_NH     0.89 (0.88, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS93_NH   0.95 (0.94, 0.96)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93_NH   6.31e-306  0.97 (0.97, 0.98)   0.92 (0.9, 0.93)
# tables/PCR_MTBLS93_NH   1.74e-304  0.97 (0.96, 0.98)   0.92 (0.9, 0.93)
# tables/PCLR_MTBLS93_NH   0.00e+00  0.93 (0.92, 0.94)  0.94 (0.93, 0.95)
# tables/RF_MTBLS93_NH    4.76e-275  0.95 (0.94, 0.95)  0.87 (0.85, 0.88)
# tables/SVM_MTBLS93_NH    0.00e+00  0.98 (0.98, 0.99)  0.95 (0.94, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93_NH   0.94 (0.93, 0.94)   0.92 (0.9, 0.95)        0.92
# tables/PCR_MTBLS93_NH   0.93 (0.93, 0.94)   0.93 (0.9, 0.95)        0.91
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)  0.95 (0.93, 0.96)        0.92
# tables/RF_MTBLS93_NH    0.85 (0.84, 0.86)  0.93 (0.91, 0.95)        0.78
# tables/SVM_MTBLS93_NH   0.95 (0.95, 0.96)  0.95 (0.94, 0.97)        0.94
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS93_NH   0.93 (0.91, 0.94)  0.65 (0.63, 0.68)
# tables/PCR_MTBLS93_NH   0.93 (0.92, 0.94)  0.65 (0.63, 0.68)
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)     nan (nan, nan)
# tables/RF_MTBLS93_NH     0.89 (0.88, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS93_NH   0.95 (0.94, 0.96)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS93_NH   6.31e-306  0.97 (0.97, 0.98)   0.92 (0.9, 0.93)
# tables/PCR_MTBLS93_NH   1.74e-304  0.97 (0.96, 0.98)   0.92 (0.9, 0.93)
# tables/PCLR_MTBLS93_NH   0.00e+00  0.93 (0.92, 0.94)  0.94 (0.93, 0.95)
# tables/RF_MTBLS93_NH    4.76e-275  0.95 (0.94, 0.95)  0.87 (0.85, 0.88)
# tables/SVM_MTBLS93_NH    0.00e+00  0.98 (0.98, 0.99)  0.95 (0.94, 0.96)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS93_NH   0.94 (0.93, 0.94)   0.92 (0.9, 0.95)        0.92
# tables/PCR_MTBLS93_NH   0.93 (0.93, 0.94)   0.93 (0.9, 0.95)        0.91
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)  0.95 (0.93, 0.96)        0.92
# tables/RF_MTBLS93_NH    0.85 (0.84, 0.86)  0.93 (0.91, 0.95)        0.78
# tables/SVM_MTBLS93_NH   0.95 (0.95, 0.96)  0.95 (0.94, 0.97)        0.94
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS93_NH   0.93 (0.91, 0.94)  0.65 (0.63, 0.68)
# tables/PCR_MTBLS93_NH   0.93 (0.92, 0.94)  0.65 (0.63, 0.68)
# tables/PCLR_MTBLS93_NH  0.94 (0.93, 0.95)     nan (nan, nan)
# tables/RF_MTBLS93_NH     0.89 (0.88, 0.9)     nan (nan, nan)
# tables/SVM_MTBLS93_NH   0.95 (0.94, 0.96)     nan (nan, nan)
