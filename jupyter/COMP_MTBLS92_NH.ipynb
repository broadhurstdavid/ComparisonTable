# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS92_NH',
        'tables/PCR_MTBLS92_NH',
        'tables/PCLR_MTBLS92_NH',
        'tables/RF_MTBLS92_NH',
        'tables/SVM_MTBLS92_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92_NH   4.32e-15  0.72 (0.67, 0.76)  0.68 (0.64, 0.73)
# tables/PCR_MTBLS92_NH   5.50e-17  0.73 (0.69, 0.79)  0.68 (0.66, 0.74)
# tables/PCLR_MTBLS92_NH  1.05e-09   0.64 (0.6, 0.68)  0.67 (0.63, 0.71)
# tables/RF_MTBLS92_NH    1.83e-24  0.79 (0.73, 0.83)  0.74 (0.68, 0.77)
# tables/SVM_MTBLS92_NH   2.23e-36  0.85 (0.81, 0.88)   0.8 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92_NH   0.59 (0.53, 0.65)  0.56 (0.46, 0.69)        0.75
# tables/PCR_MTBLS92_NH   0.61 (0.55, 0.67)  0.53 (0.47, 0.66)        0.78
# tables/PCLR_MTBLS92_NH  0.59 (0.51, 0.66)  0.51 (0.44, 0.57)        0.77
# tables/RF_MTBLS92_NH    0.69 (0.61, 0.72)  0.62 (0.48, 0.68)        0.82
# tables/SVM_MTBLS92_NH    0.8 (0.76, 0.83)  0.65 (0.57, 0.71)         0.9
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS92_NH   0.57 (0.49, 0.67)  0.14 (0.07, 0.19)
# tables/PCR_MTBLS92_NH   0.56 (0.51, 0.67)   0.16 (0.1, 0.23)
# tables/PCLR_MTBLS92_NH   0.55 (0.49, 0.6)     nan (nan, nan)
# tables/RF_MTBLS92_NH     0.65 (0.55, 0.7)     nan (nan, nan)
# tables/SVM_MTBLS92_NH   0.72 (0.65, 0.76)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92_NH   4.32e-15  0.72 (0.67, 0.76)  0.68 (0.64, 0.73)
# tables/PCR_MTBLS92_NH   5.50e-17  0.73 (0.69, 0.79)  0.68 (0.66, 0.74)
# tables/PCLR_MTBLS92_NH  1.05e-09   0.64 (0.6, 0.68)  0.67 (0.63, 0.71)
# tables/RF_MTBLS92_NH    1.83e-24  0.79 (0.73, 0.83)  0.74 (0.68, 0.77)
# tables/SVM_MTBLS92_NH   2.23e-36  0.85 (0.81, 0.88)   0.8 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92_NH   0.59 (0.53, 0.65)  0.56 (0.46, 0.69)        0.75
# tables/PCR_MTBLS92_NH   0.61 (0.55, 0.67)  0.53 (0.47, 0.66)        0.78
# tables/PCLR_MTBLS92_NH  0.59 (0.51, 0.66)  0.51 (0.44, 0.57)        0.77
# tables/RF_MTBLS92_NH    0.69 (0.61, 0.72)  0.62 (0.48, 0.68)        0.82
# tables/SVM_MTBLS92_NH    0.8 (0.76, 0.83)  0.65 (0.57, 0.71)         0.9
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS92_NH   0.57 (0.49, 0.67)  0.14 (0.07, 0.19)
# tables/PCR_MTBLS92_NH   0.56 (0.51, 0.67)   0.16 (0.1, 0.23)
# tables/PCLR_MTBLS92_NH   0.55 (0.49, 0.6)     nan (nan, nan)
# tables/RF_MTBLS92_NH     0.65 (0.55, 0.7)     nan (nan, nan)
# tables/SVM_MTBLS92_NH   0.72 (0.65, 0.76)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                        manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS92_NH   4.32e-15  0.72 (0.67, 0.76)  0.68 (0.64, 0.73)
# tables/PCR_MTBLS92_NH   5.50e-17  0.73 (0.69, 0.79)  0.68 (0.66, 0.74)
# tables/PCLR_MTBLS92_NH  1.05e-09   0.64 (0.6, 0.68)  0.67 (0.63, 0.71)
# tables/RF_MTBLS92_NH    1.83e-24  0.79 (0.73, 0.83)  0.74 (0.68, 0.77)
# tables/SVM_MTBLS92_NH   2.23e-36  0.85 (0.81, 0.88)   0.8 (0.77, 0.83)
#
#                                 precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS92_NH   0.59 (0.53, 0.65)  0.56 (0.46, 0.69)        0.75
# tables/PCR_MTBLS92_NH   0.61 (0.55, 0.67)  0.53 (0.47, 0.66)        0.78
# tables/PCLR_MTBLS92_NH  0.59 (0.51, 0.66)  0.51 (0.44, 0.57)        0.77
# tables/RF_MTBLS92_NH    0.69 (0.61, 0.72)  0.62 (0.48, 0.68)        0.82
# tables/SVM_MTBLS92_NH    0.8 (0.76, 0.83)  0.65 (0.57, 0.71)         0.9
#
#                                   F1score                 R2
# method
# tables/PLS_MTBLS92_NH   0.57 (0.49, 0.67)  0.14 (0.07, 0.19)
# tables/PCR_MTBLS92_NH   0.56 (0.51, 0.67)   0.16 (0.1, 0.23)
# tables/PCLR_MTBLS92_NH   0.55 (0.49, 0.6)     nan (nan, nan)
# tables/RF_MTBLS92_NH     0.65 (0.55, 0.7)     nan (nan, nan)
# tables/SVM_MTBLS92_NH   0.72 (0.65, 0.76)     nan (nan, nan)
