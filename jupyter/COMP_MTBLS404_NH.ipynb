# %%
# 1. Import Packages/Modules

import cimcb as cb
# Out:
# Using TensorFlow backend.

# %%
# 2. Locate xlsx files


file = ['tables/PLS_MTBLS404_NH',
        'tables/PCR_MTBLS404_NH',
        'tables/PCLR_MTBLS404_NH',
        'tables/RF_MTBLS404_NH',
        'tables/SVM_MTBLS404_NH']

# %%
# 3. Train Table

train = cb.utils.load_comparisonXL(file, "train")
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404_NH   3.21e-29   0.98 (0.96, 1.0)   0.94 (0.8, 0.97)
# tables/PCR_MTBLS404_NH   8.83e-25  0.94 (0.91, 0.97)   0.89 (0.8, 0.92)
# tables/PCLR_MTBLS404_NH  2.33e-23  0.87 (0.83, 0.91)  0.87 (0.82, 0.91)
# tables/RF_MTBLS404_NH    8.36e-28  0.97 (0.94, 0.99)   0.9 (0.85, 0.93)
# tables/SVM_MTBLS404_NH   2.30e-31     1.0 (1.0, 1.0)  0.98 (0.97, 0.98)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404_NH   0.94 (0.91, 0.96)   0.95 (0.72, 1.0)        0.93
# tables/PCR_MTBLS404_NH   0.88 (0.82, 0.91)  0.92 (0.76, 0.98)        0.84
# tables/PCLR_MTBLS404_NH   0.87 (0.8, 0.93)  0.89 (0.83, 0.93)        0.84
# tables/RF_MTBLS404_NH     0.9 (0.87, 0.93)  0.92 (0.82, 0.98)        0.88
# tables/SVM_MTBLS404_NH   0.96 (0.95, 0.98)     1.0 (1.0, 1.0)        0.95
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS404_NH   0.95 (0.81, 0.97)  0.69 (0.63, 0.75)
# tables/PCR_MTBLS404_NH     0.9 (0.8, 0.94)  0.54 (0.46, 0.61)
# tables/PCLR_MTBLS404_NH  0.88 (0.83, 0.92)     nan (nan, nan)
# tables/RF_MTBLS404_NH    0.91 (0.85, 0.95)     nan (nan, nan)
# tables/SVM_MTBLS404_NH   0.98 (0.97, 0.99)     nan (nan, nan)

# %%
# 4. In Bag Table

train = cb.utils.load_comparisonXL(file, 'in bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404_NH   3.21e-29   0.98 (0.96, 1.0)   0.94 (0.8, 0.97)
# tables/PCR_MTBLS404_NH   8.83e-25  0.94 (0.91, 0.97)   0.89 (0.8, 0.92)
# tables/PCLR_MTBLS404_NH  2.33e-23  0.87 (0.83, 0.91)  0.87 (0.82, 0.91)
# tables/RF_MTBLS404_NH    8.36e-28  0.97 (0.94, 0.99)   0.9 (0.85, 0.93)
# tables/SVM_MTBLS404_NH   2.30e-31     1.0 (1.0, 1.0)  0.98 (0.97, 0.98)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404_NH   0.94 (0.91, 0.96)   0.95 (0.72, 1.0)        0.93
# tables/PCR_MTBLS404_NH   0.88 (0.82, 0.91)  0.92 (0.76, 0.98)        0.84
# tables/PCLR_MTBLS404_NH   0.87 (0.8, 0.93)  0.89 (0.83, 0.93)        0.84
# tables/RF_MTBLS404_NH     0.9 (0.87, 0.93)  0.92 (0.82, 0.98)        0.88
# tables/SVM_MTBLS404_NH   0.96 (0.95, 0.98)     1.0 (1.0, 1.0)        0.95
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS404_NH   0.95 (0.81, 0.97)  0.69 (0.63, 0.75)
# tables/PCR_MTBLS404_NH     0.9 (0.8, 0.94)  0.54 (0.46, 0.61)
# tables/PCLR_MTBLS404_NH  0.88 (0.83, 0.92)     nan (nan, nan)
# tables/RF_MTBLS404_NH    0.91 (0.85, 0.95)     nan (nan, nan)
# tables/SVM_MTBLS404_NH   0.98 (0.97, 0.99)     nan (nan, nan)

# %%
# 4. Out of bag

train = cb.utils.load_comparisonXL(file, 'out of bag')
display(train)
# Out:
#                         manw_pval                auc           accuracy  \
# method
# tables/PLS_MTBLS404_NH   3.21e-29   0.98 (0.96, 1.0)   0.94 (0.8, 0.97)
# tables/PCR_MTBLS404_NH   8.83e-25  0.94 (0.91, 0.97)   0.89 (0.8, 0.92)
# tables/PCLR_MTBLS404_NH  2.33e-23  0.87 (0.83, 0.91)  0.87 (0.82, 0.91)
# tables/RF_MTBLS404_NH    8.36e-28  0.97 (0.94, 0.99)   0.9 (0.85, 0.93)
# tables/SVM_MTBLS404_NH   2.30e-31     1.0 (1.0, 1.0)  0.98 (0.97, 0.98)
#
#                                  precision        sensitivity specificity  \
# method
# tables/PLS_MTBLS404_NH   0.94 (0.91, 0.96)   0.95 (0.72, 1.0)        0.93
# tables/PCR_MTBLS404_NH   0.88 (0.82, 0.91)  0.92 (0.76, 0.98)        0.84
# tables/PCLR_MTBLS404_NH   0.87 (0.8, 0.93)  0.89 (0.83, 0.93)        0.84
# tables/RF_MTBLS404_NH     0.9 (0.87, 0.93)  0.92 (0.82, 0.98)        0.88
# tables/SVM_MTBLS404_NH   0.96 (0.95, 0.98)     1.0 (1.0, 1.0)        0.95
#
#                                    F1score                 R2
# method
# tables/PLS_MTBLS404_NH   0.95 (0.81, 0.97)  0.69 (0.63, 0.75)
# tables/PCR_MTBLS404_NH     0.9 (0.8, 0.94)  0.54 (0.46, 0.61)
# tables/PCLR_MTBLS404_NH  0.88 (0.83, 0.92)     nan (nan, nan)
# tables/RF_MTBLS404_NH    0.91 (0.85, 0.95)     nan (nan, nan)
# tables/SVM_MTBLS404_NH   0.98 (0.97, 0.99)     nan (nan, nan)
